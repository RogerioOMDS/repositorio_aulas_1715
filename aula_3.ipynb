# %% [markdown]
# # Aula 3 - Numpy e Pandas
#
# Nessa aula, iremos tratar dos seguintes conteúdos:
# - Numpy Matrizes
# - Métodos de Matrizes Numpy
# - Pandas
# - Series
# - Métodos Pandas
# - DataFrames
# - Trabalhando com CSVs

# %% [markdown]
# <img src="data:image/png;base64,..." width=800>

# %% [markdown]
# ## Pandas

# %% [markdown]
# __Pandas__ é um pacote python construído com base no __NumPy__ e __Matplotlib__ que busca organizar dados no formato de tabela, atribuindo rótulos às linhas e colunas. O pacote __Pandas__ fornece ainda um conjunto de funcionalidades que permite processar as informações de tabelas de forma bastante eficiente, implementando métodos fundamentais para fins de tratamento de dados.
#
# O Pandas organiza os dados nos seguintes tipos de estruturas:
# - Series (Séries)
# - DataFrame

# %% [markdown]
#  O __Pandas__ é um pacote e para utilizarmos, devemos importá-lo para o nosso notebook da seguinte forma:

# %%
# import da bibloteca do Pandas

import pandas as pd

# %%
# !pip install pandas 
# %pip install pandas

# %% [markdown]
# ##

# %% [markdown]
# ### Series
# A estrutura de representação tipo __Series__ do __Pandas__ é semelhante a um array unidimensional, porém os elementos podem ser indexados por números inteiros (como em um array do NumPy) ou por meio de rótulos (labels) que não precisam ser únicos e podem ser organizados de forma hierárquica.
# - Quando os índices ou rótulos não são informados explicitamente, Pandas cria uma indexação com números inteiros automaticamente, variando os índices de $0$ (zero) a $n-1$, onde $n$ é o número de elementos na série.
# - Os rótulos são usados para realizar buscas rápidas, alinhamento de dados e operações de junção de dados.

# %% [markdown]
# #### Criando séries com Pandas
# Séries podem ser criadas no Pandas de diferentes formas, a partir de:
# - Listas ou Arrays
# - Dicionários
# - DataFrames

# %% [markdown]
# ### Utilizando Listas ou Arrays

# %%
# Vamos criar uma Serie a partir de uma lista do Python
lista = [12, 23, 34, 45, 56, 67, 78, 89]

# Define a Serie
series = pd.Series(data=lista)

# Mostra o resultado para a Serie criada
series
# Out:
# 0    12
# 1    23
# 2    34
# 3    45
# 4    56
# 5    67
# 6    78
# 7    89
# dtype: int64

# %%
type(series)
# Out:
# pandas.Series

# %% [markdown]
# Agora vamos criar uma Serie a partir de um __np.array__:

# %%
# Vamos criar uma Serie a partir de uma lista do Python
import numpy as np

# Cria um array usando a função np.array
array = np.arange(0, 50, 3)

# Cria a Serie a partir do array
serie_multiplos_3 = pd.Series(array)

# Mostra o resultado da Serie criada
serie_multiplos_3
# Out:
# 0      0
# 1      3
# 2      6
# 3      9
# 4     12
# 5     15
# 6     18
# 7     21
# 8     24
# 9     27
# 10    30
# 11    33
# 12    36
# 13    39
# 14    42
# 15    45
# 16    48
# dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# ### Indexação
#
# Assim como para os arrays, conseguimos acessar diversos elementos da __Serie__ a partir dos __índices:__

# %%
lista[-1]
# Out:
# 89

# %%
series[0]
# Out:
# np.int64(12)

# %%
serie_multiplos_3[4]
# Out:
# np.int64(12)

# %% [markdown]
# Da mesma forma, conseguimos fazer o __Slicing__ em uma __Serie__:

# %%
serie_multiplos_3[ 1 : 9 : 2]
# Out:
# 1     3
# 3     9
# 5    15
# 7    21
# dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# ##

# %% [markdown]
# ### Operações Matemáticas
#
# De maneira análoga ao que fizemos usando os __arrays__, pode-se fazer qualquer tipo de manipulação matemática utilizando as __Series__:

# %%
# Podemos criar Series a partir de Dicionarios tambem!

# Define o dicionario e seus elementos
dicionario = {'Tomate': 3.50, 'Agua' : 3, 'Coca-cola' : 9.40}

# Cria a Serie a partir dee um dicionário
serie_precos = pd.Series(dicionario)

# Mostra o resultado da Serie criada
print(serie_precos)
## O tipo de dado do indice é object -> Quer dizer que o pandas não sabe o que é
## Tipicamente é uma string
# Out:
# Tomate       3.5
# Agua         3.0
# Coca-cola    9.4
# dtype: float64

# %%
serie_precos
# Out:
# Tomate       3.5
# Agua         3.0
# Coca-cola    9.4
# dtype: float64

# %%
## Adicionei um valor
serie_precos['Frango'] = 8.30

# %%
serie_precos
# Out:
# Tomate       3.5
# Agua         3.0
# Coca-cola    9.4
# Frango       8.3
# dtype: float64

# %%
# Podemos fazer manipulações matemáticas utilizando as Series
# Adicionando o valor 10 para cada elemento da Serie
serie_precos + 10
# Out:
# Tomate       13.5
# Agua         13.0
# Coca-cola    19.4
# Frango       18.3
# dtype: float64

# %%
serie_precos * 10
# Out:
# Tomate       35.0
# Agua         30.0
# Coca-cola    94.0
# Frango       83.0
# dtype: float64

# %%
# Dividindo cada elemento da Serie por 5
serie_precos / 5
# Out:
# Tomate       0.70
# Agua         0.60
# Coca-cola    1.88
# Frango       1.66
# dtype: float64

# %%
## Somando uma porcentagem
serie_precos * (1 + (10/100))
# Out:
# Tomate        3.85
# Agua          3.30
# Coca-cola    10.34
# Frango        9.13
# dtype: float64

# %%
# Divide o valor 300 por cada um dos elementos da Serie
300 / serie_precos
# Out:
# Tomate        85.714286
# Agua         100.000000
# Coca-cola     31.914894
# Frango        36.144578
# dtype: float64

# %% [markdown]
# ##

# %% [markdown]
# ## Métodos Pandas (Series)
#
# Justamente pela biblioteca __Pandas__ utilizando do NumPy para a construção da sua arquitetura, muito dos métodos que são nativos do NumPy também vão funcionar com o __Pandas__, além de alguns novos métodos que veremos a seguir:

# %%
# Vamos agora criar uma série e armazenar notas de alunos da Let's Code

# Cria Serie com valores de notas para cada aluno
notas = pd.Series([10, 8, 6.5, 9, 7.5, 8.5, 9, 9, 4, 8.5, 7.5,
                   8, 10, 10, 4.5, 4.5, 9, 8, 8, 9, 9, 9, 6.5,
                   5, 6, 4.5, 9, 10, 1, 0,5, 7, 9, 6.5, 5, 8])

# Mostra o resultado da Serie criada
notas
# Out:
# 0     10.0
# 1      8.0
# 2      6.5
# 3      9.0
# 4      7.5
# 5      8.5
# 6      9.0
# 7      9.0
# 8      4.0
# 9      8.5
# 10     7.5
# 11     8.0
# 12    10.0
# 13    10.0
# 14     4.5
# 15     4.5
# 16     9.0
# 17     8.0
# 18     8.0
# 19     9.0
# 20     9.0
# 21     9.0
# 22     6.5
# 23     5.0
# 24     6.0
# 25     4.5
# 26     9.0
# 27    10.0
# 28     1.0
# 29     0.0
# 30     5.0
# 31     7.0
# 32     9.0
# 33     6.5
# 34     5.0
# 35     8.0
# dtype: float64

# %%
notas.shape
# Out:
# (36,)

# %% [markdown]
# __sort_values__: este método ordena a Serie de acordo com os valores númericos dos elementos:

# %%
notas.sort_values()
# Out:
# 29     0.0
# 28     1.0
# 8      4.0
# 15     4.5
# 14     4.5
# 25     4.5
# 23     5.0
# 30     5.0
# 34     5.0
# 24     6.0
# 2      6.5
# 22     6.5
# 33     6.5
# 31     7.0
# 10     7.5
# 4      7.5
# 18     8.0
# 17     8.0
# 1      8.0
# 11     8.0
# 35     8.0
# 9      8.5
# 5      8.5
# 6      9.0
# 20     9.0
# 21     9.0
# 26     9.0
# 19     9.0
# 32     9.0
# 3      9.0
# 16     9.0
# 7      9.0
# 27    10.0
# 0     10.0
# 13    10.0
# 12    10.0
# dtype: float64

# %%
# Ordenar as notas pelo valor delas:
notas.sort_values(ascending = False)# -> Se quiser editar direto na serie passo esse "inplace=True"
# Out:
# 0     10.0
# 27    10.0
# 12    10.0
# 13    10.0
# 21     9.0
# 26     9.0
# 3      9.0
# 7      9.0
# 16     9.0
# 19     9.0
# 20     9.0
# 6      9.0
# 32     9.0
# 5      8.5
# 9      8.5
# 1      8.0
# 35     8.0
# 17     8.0
# 11     8.0
# 18     8.0
# 10     7.5
# 4      7.5
# 31     7.0
# 2      6.5
# 33     6.5
# 22     6.5
# 24     6.0
# 30     5.0
# 34     5.0
# 23     5.0
# 15     4.5
# 14     4.5
# 25     4.5
# 8      4.0
# 28     1.0
# 29     0.0
# dtype: float64

# %%
notas
# Out:
# 0     10.0
# 1      8.0
# 2      6.5
# 3      9.0
# 4      7.5
# 5      8.5
# 6      9.0
# 7      9.0
# 8      4.0
# 9      8.5
# 10     7.5
# 11     8.0
# 12    10.0
# 13    10.0
# 14     4.5
# 15     4.5
# 16     9.0
# 17     8.0
# 18     8.0
# 19     9.0
# 20     9.0
# 21     9.0
# 22     6.5
# 23     5.0
# 24     6.0
# 25     4.5
# 26     9.0
# 27    10.0
# 28     1.0
# 29     0.0
# 30     5.0
# 31     7.0
# 32     9.0
# 33     6.5
# 34     5.0
# 35     8.0
# dtype: float64

# %%
notas.sort_values(ascending = False, inplace = True)

# %%
notas
# Out:
# 0     10.0
# 27    10.0
# 12    10.0
# 13    10.0
# 21     9.0
# 26     9.0
# 3      9.0
# 7      9.0
# 16     9.0
# 19     9.0
# 20     9.0
# 6      9.0
# 32     9.0
# 5      8.5
# 9      8.5
# 1      8.0
# 35     8.0
# 17     8.0
# 11     8.0
# 18     8.0
# 10     7.5
# 4      7.5
# 31     7.0
# 2      6.5
# 33     6.5
# 22     6.5
# 24     6.0
# 30     5.0
# 34     5.0
# 23     5.0
# 15     4.5
# 14     4.5
# 25     4.5
# 8      4.0
# 28     1.0
# 29     0.0
# dtype: float64

# %% [markdown]
# __unique:__ este método retorna todos os __valores distintos__ dentro de uma __Serie__:

# %%
notas.unique()
# Out:
# array([10. ,  9. ,  8.5,  8. ,  7.5,  7. ,  6.5,  6. ,  5. ,  4.5,  4. ,
#         1. ,  0. ])

# %% [markdown]
# __nunique:__ este método retorna a quantidade de __valores distintos__ dentro de uma __Serie__:

# %%
notas.nunique()
# Out:
# 13

# %% [markdown]
# __value_counts:__ este método retorna as __frequências (contagens)__ para cada um dos __elementos distintos__ dentro de uma Serie:

# %%
notas.value_counts()
# Out:
# 9.0     9
# 8.0     5
# 10.0    4
# 6.5     3
# 5.0     3
# 4.5     3
# 8.5     2
# 7.5     2
# 7.0     1
# 6.0     1
# 4.0     1
# 1.0     1
# 0.0     1
# Name: count, dtype: int64

# %% [markdown]
# Podemos também ao invés de retorna as frequências, retornar as __proporções__ de cada um dos __elementos distintos__:

# %%
# tabela de frequência relativa
notas.value_counts(normalize=True)
# Out:
# 9.0     0.250000
# 8.0     0.138889
# 10.0    0.111111
# 6.5     0.083333
# 5.0     0.083333
# 4.5     0.083333
# 8.5     0.055556
# 7.5     0.055556
# 7.0     0.027778
# 6.0     0.027778
# 4.0     0.027778
# 1.0     0.027778
# 0.0     0.027778
# Name: proportion, dtype: float64

# %%
# frequência percentual
notas.value_counts(normalize=True)*100
# Out:
# 9.0     25.000000
# 8.0     13.888889
# 10.0    11.111111
# 6.5      8.333333
# 5.0      8.333333
# 4.5      8.333333
# 8.5      5.555556
# 7.5      5.555556
# 7.0      2.777778
# 6.0      2.777778
# 4.0      2.777778
# 1.0      2.777778
# 0.0      2.777778
# Name: proportion, dtype: float64

# %%
notas.value_counts(normalize = True).mul(100).round(2).astype(str) + " %"
# Out:
# 9.0      25.0 %
# 8.0     13.89 %
# 10.0    11.11 %
# 6.5      8.33 %
# 5.0      8.33 %
# 4.5      8.33 %
# 8.5      5.56 %
# 7.5      5.56 %
# 7.0      2.78 %
# 6.0      2.78 %
# 4.0      2.78 %
# 1.0      2.78 %
# 0.0      2.78 %
# Name: proportion, dtype: str

# %% [markdown]
# A seguir teremos alguns outros métodos já conhecidos do __NumPy__ que retorna algumas estatísticas básicas para a Serie:

# %%
# calcula a soma das notas
notas.sum()
# Out:
# np.float64(259.0)

# %%
# Retorna o maior valor da Serie
notas.max()
# Out:
# np.float64(10.0)

# %%
# Retorna o menor valor da Serie
notas.min()
# Out:
# np.float64(0.0)

# %%
# Calcula a media das notas da Serie
notas.mean()
# Out:
# np.float64(7.194444444444445)

# %%
# Calcula o Desvio padrão das notas
notas.std()
# Out:
# np.float64(2.4327461783453628)

# %%
# Calcula a mediana das notas das Series (termo central dos valores)
notas.median()
# Out:
# np.float64(8.0)

# %%
# Calcula a moda das notas (a nota mais frequente)
notas.mode()
# Out:
# 0    9.0
# dtype: float64

# %% [markdown]
# # PROJETO
#
# Tratamento e análise de dados com Pandas
#
# 1. Procurar um dataset (Conjunto de dados) interessante;
#     - Kaggle;
#     - UCI Datasets;
#     - IBGE;
#     - Outras fontes de interesse.
# 2. Descrever os dados (nulos, valores distintos, tipos de variáveis...);
# 3. Fazer o tratamento de qualidade dos dados (Remover nulos, remover valores constantes, ...)
# 4. Levantar 10 perguntas sobre o dataset e responder utilizado filtragens, agrupamentos e transformações no Pandas.
#
# Entrega:
#
# - Repositório do github (Envie o link do repositório);
# - Pelo menos 3 commits no github ;
# - No repositório deve conter o dataset e o arquivo .ipynb;
# - Entrega até o dia 03/10 no LMS;

# %% [markdown]
# # Porque média e mediana?

# %%
# Média é sensível a outliers 

lista_sanduiches = [2,1,3,2,1]

print("Média: ", np.mean(lista_sanduiches))
print("Mediana: ", np.median(lista_sanduiches))
# Out:
# Média:  1.8
# Mediana:  2.0

# %%
# Mediana não é sensível a outliers

lista_sanduiches = [2,1,3,20,1]

print("Média: ", np.mean(lista_sanduiches))
print("Mediana: ", np.median(lista_sanduiches))
# Out:
# Média:  5.4
# Mediana:  2.0

# %% [markdown]
# # Moda
#
# - unimodal: uma moda
# - bimodal: 2 modas
# - trimodal: 3 modas
# - multimodal/polimodal: 4 ou mais modas
# - amodal: sem moda

# %%
lista_numeros = [1,1,1,2,2,2,3,3,4,4]
serie_numeros = pd.Series(lista_numeros)
serie_numeros
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    2
# 5    2
# 6    3
# 7    3
# 8    4
# 9    4
# dtype: int64

# %%
serie_numeros.mode()
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
notas.median()
# Out:
# np.float64(8.0)

# %%
notas.mean()
# Out:
# np.float64(7.194444444444445)

# %%
notas.std()
# Out:
# np.float64(2.4327461783453628)

# %% [markdown]
# __describe:__ este é um método muito útil que vai trazer um resumos das __principais estátisticas__ da Serie que estamops trabalhando:

# %%
notas.describe()
# Out:
# count    36.000000
# mean      7.194444
# std       2.432746
# min       0.000000
# 25%       5.750000
# 50%       8.000000
# 75%       9.000000
# max      10.000000
# dtype: float64

# %%
# primeiro quartil
notas.quantile(0.25)
# Out:
# np.float64(5.75)

# %%
# segundo quartil (mediana)
notas.quantile(0.5)
# Out:
# np.float64(8.0)

# %%
# terceiro quartil 
notas.quantile(0.75)
# Out:
# np.float64(9.0)

# %% [markdown]
# ##

# %% [markdown]
# ## Exercícios

# %% [markdown]
# **1)** Cria uma série de pandas que tenha os números inteiros de 0 a 100.

# %%
import pandas as pd

# %% [markdown]
# **2)** Considere uma série de notas de alunos:
#
#  notas = pd.Series([10, 8, 6.5, 9, 7.5, 8.5, 9, 9, 4, 8.5, 7.5,
#                    8, 10, 10, 4.5, 4.5, 9, 8, 8, 9, 9, 9, 6.5,
#                    5, 6, 4.5, 9, 10, 1, 0,5, 7, 9, 6.5, 5, 8])
#
# Determine:
#
# **a)** A nota média
#
# **b)** O desvio padrão
#
# **c)** A moda
#
# **d)** A mediana

# %%
notas = pd.Series([10, 8, 6.5, 9, 7.5, 8.5, 9, 9, 4, 8.5, 7.5,
                8, 10, 10, 4.5, 4.5, 9, 8, 8, 9, 9, 9, 6.5,
                5, 6, 4.5, 9, 10, 1, 0,5, 7, 9, 6.5, 5, 8])

# %%
media = notas.mean() 
desvio_padrao = notas.std() 
moda = notas.mode()
mediana = notas.median()

# %%
media
# Out:
# np.float64(7.194444444444445)

# %%
desvio_padrao
# Out:
# np.float64(2.4327461783453628)

# %%
round(desvio_padrao, 2)
# Out:
# np.float64(2.43)

# %%
moda
# Out:
# 0    9.0
# dtype: float64

# %%
mediana
# Out:
# np.float64(8.0)

# %% [markdown]
# ## DataFrame

# %% [markdown]
# __DataFrames__ assim como na mesma analogia para as matrizes, são um __conjunto de Series__ que vão ser bem caracterizados pelo o seu formato tabular (o que facilita muito o processo de manipulação dos dados!):

# %%
# Cria um dicionario com nomes de alunos e suas respectivas notas
dictionary = {'Alunos': ['Sandro', 'Rafael', 'Tiago', 'André', 'Camila', 'Teo', 'Carlos', 'Juca', 'Carla'],
              'Notas': [8, 10, 9.5, 7.5, 9.5, 10, 5, 6.5, 10]}

# Cria um DataFrame a partir de um dicionario
df = pd.DataFrame(data = dictionary)

# Mostra o resultado do DataFrame
df
# Out:
#    Alunos  Notas
# 0  Sandro    8.0
# 1  Rafael   10.0
# 2   Tiago    9.5
# 3   André    7.5
# 4  Camila    9.5
# 5     Teo   10.0
# 6  Carlos    5.0
# 7    Juca    6.5
# 8   Carla   10.0

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df["Notas"]
# Out:
# 0     8.0
# 1    10.0
# 2     9.5
# 3     7.5
# 4     9.5
# 5    10.0
# 6     5.0
# 7     6.5
# 8    10.0
# Name: Notas, dtype: float64

# %%
type(df["Notas"])
# Out:
# pandas.Series

# %%
df
# Out:
#    Alunos  Notas
# 0  Sandro    8.0
# 1  Rafael   10.0
# 2   Tiago    9.5
# 3   André    7.5
# 4  Camila    9.5
# 5     Teo   10.0
# 6  Carlos    5.0
# 7    Juca    6.5
# 8   Carla   10.0

# %%
df["Notas"].mean()
# Out:
# np.float64(8.444444444444445)

# %%
df["Notas"].median()
# Out:
# np.float64(9.5)

# %%
df['Notas'].std()
# Out:
# np.float64(1.8104634152000358)

# %%
df["Notas"].describe()
# Out:
# count     9.000000
# mean      8.444444
# std       1.810463
# min       5.000000
# 25%       7.500000
# 50%       9.500000
# 75%      10.000000
# max      10.000000
# Name: Notas, dtype: float64

# %%
df
# Out:
#    Alunos  Notas
# 0  Sandro    8.0
# 1  Rafael   10.0
# 2   Tiago    9.5
# 3   André    7.5
# 4  Camila    9.5
# 5     Teo   10.0
# 6  Carlos    5.0
# 7    Juca    6.5
# 8   Carla   10.0

# %%
df["Notas"] * 2
# Out:
# 0    16.0
# 1    20.0
# 2    19.0
# 3    15.0
# 4    19.0
# 5    20.0
# 6    10.0
# 7    13.0
# 8    20.0
# Name: Notas, dtype: float64

# %%
df["dobro_notas"] = df["Notas"] * 2

# %%
df["soma_notas"] = df["Notas"] + df["dobro_notas"]

# %%
df
# Out:
#    Alunos  Notas  dobro_notas  soma_notas
# 0  Sandro    8.0         16.0        24.0
# 1  Rafael   10.0         20.0        30.0
# 2   Tiago    9.5         19.0        28.5
# 3   André    7.5         15.0        22.5
# 4  Camila    9.5         19.0        28.5
# 5     Teo   10.0         20.0        30.0
# 6  Carlos    5.0         10.0        15.0
# 7    Juca    6.5         13.0        19.5
# 8   Carla   10.0         20.0        30.0

# %%
df["Notas"].sum(0)
# Out:
# C:\Users\r-omd\AppData\Local\Temp\ipykernel_32692\2098525133.py:1: Pandas4Warning: Starting with pandas version 4.0 all arguments of sum will be keyword-only.
#   df["Notas"].sum(0)
# np.float64(76.0)

# %%
df["dobro_notas"].sum()
# Out:
# np.float64(152.0)

# %%
df[ ["Notas", "dobro_notas","soma_notas"]  ].sum(axis = 0)
# Out:
# Notas           76.0
# dobro_notas    152.0
# soma_notas     228.0
# dtype: float64

# %%
df[ ["Notas", "dobro_notas","soma_notas"]  ].sum(axis = 1)
# Out:
# 0    48.0
# 1    60.0
# 2    57.0
# 3    45.0
# 4    57.0
# 5    60.0
# 6    30.0
# 7    39.0
# 8    60.0
# dtype: float64

# %%
df["soma_total"] = df[ ["Notas", "dobro_notas","soma_notas"]  ].sum(axis = 1)

# %%
df
# Out:
#    Alunos  Notas  dobro_notas  soma_notas  soma_total
# 0  Sandro    8.0         16.0        24.0        48.0
# 1  Rafael   10.0         20.0        30.0        60.0
# 2   Tiago    9.5         19.0        28.5        57.0
# 3   André    7.5         15.0        22.5        45.0
# 4  Camila    9.5         19.0        28.5        57.0
# 5     Teo   10.0         20.0        30.0        60.0
# 6  Carlos    5.0         10.0        15.0        30.0
# 7    Juca    6.5         13.0        19.5        39.0
# 8   Carla   10.0         20.0        30.0        60.0

# %% [markdown]
# ## Máscaras Booleanas
#
# Podemos fazer filtros no __DataFrame__ definindo como que para os arrays, as __máscaras booleanas:__

# %%
df_filtrado = df[ df["Notas"] > 8 ]

# %%
df_filtrado
# Out:
#    Alunos  Notas  dobro_notas  soma_notas  soma_total
# 1  Rafael   10.0         20.0        30.0        60.0
# 2   Tiago    9.5         19.0        28.5        57.0
# 4  Camila    9.5         19.0        28.5        57.0
# 5     Teo   10.0         20.0        30.0        60.0
# 8   Carla   10.0         20.0        30.0        60.0

# %%
df[ df["Notas"] % 2 == 0   ]
# Out:
#    Alunos  Notas  dobro_notas  soma_notas  soma_total
# 0  Sandro    8.0         16.0        24.0        48.0
# 1  Rafael   10.0         20.0        30.0        60.0
# 5     Teo   10.0         20.0        30.0        60.0
# 8   Carla   10.0         20.0        30.0        60.0

# %%
mascara_pares = df["Notas"] % 2 == 0
mascara_pares
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: Notas, dtype: bool

# %%
df[mascara_pares]
# Out:
#    Alunos  Notas  dobro_notas  soma_notas  soma_total
# 0  Sandro    8.0         16.0        24.0        48.0
# 1  Rafael   10.0         20.0        30.0        60.0
# 5     Teo   10.0         20.0        30.0        60.0
# 8   Carla   10.0         20.0        30.0        60.0

# %%
maior_que_9 =  df["Notas"] > 9 
menor_ou_igual_a_5 = df["Notas"] <= 5

# %%
df[menor_ou_igual_a_5]
# Out:
#    Alunos  Notas
# 6  Carlos    5.0

# %%
df[maior_que_9]
# Out:
#    Alunos  Notas
# 1  Rafael   10.0
# 2   Tiago    9.5
# 4  Camila    9.5
# 5     Teo   10.0
# 8   Carla   10.0

# %%
# (maior que 9) ou (menor ou igual a 5)
df[maior_que_9 | menor_ou_igual_a_5]
# Out:
#    Alunos  Notas
# 1  Rafael   10.0
# 2   Tiago    9.5
# 4  Camila    9.5
# 5     Teo   10.0
# 6  Carlos    5.0
# 8   Carla   10.0

# %%
# (maior que 9) E (menor ou igual a 5)
df[maior_que_9 & menor_ou_igual_a_5]
# Out:
# Empty DataFrame
# Columns: [Alunos, Notas]
# Index: []

# %%
df[ (df["Notas"] > 9) | (df["Notas"] <= 5)  ]
# Out:
#    Alunos  Notas
# 1  Rafael   10.0
# 2   Tiago    9.5
# 4  Camila    9.5
# 5     Teo   10.0
# 6  Carlos    5.0
# 8   Carla   10.0

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Para o Dataframe de Alunos utilizado

# %% [markdown]
# **1)** Encontre a nota média dos alunos

# %% [markdown]
# **2)** A nota do Juca

# %% [markdown]
# **3)** Os alunos com nota menor que 6.5

# %% [markdown]
# **4)** Peça a descrição das notas para ter insights interessantes

# %% [markdown]
# **5)** A moda das notas acima de 7

# %% [markdown]
# ##

# %% [markdown]
# ##

# %% [markdown]
# ## Trabalhando com CSVs

# %% [markdown]
# O __Pandas__ tem algumas funcionalidades bem interessantes, como por exemplo permitir que carregue para o Notebook arquivos no formato csv, excel, xlsx e etc. Vamos ver uma aplicação como o CSV:

# %% [markdown]
# [Neste Link](https://www.kaggle.com/c/titanic/data), conseguimos mais informações sobre a base de dados do Titanic! O Kaggle é uma plataforma muito conheciida no quesito de competições de Data Science e Machine Learning, além de disponibilizar diversos conjuntos de dados para treinarmos =)

# %% [markdown]
# Vamos testar alguns outros __métodos__ disponíveis para os DaataFrames:

# %% [markdown]
# __Método head/tail:__ São métodos muito importantes que mostram na tela as primeiras e últimas linhas respectivamente de um __DataFrame__:

# %% [markdown]
# ##

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
# linhas e coluns
titanic.shape
# Out:
# (891, 12)

# %%
# quero ver as 5 primeiras linhas 
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# quero ver a 2 ultimas linhas 
titanic.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
# Quantos dados nulos? 

titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Quantos dados nulos? 

titanic.isnull().sum() * 100/ titanic.shape[0]
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
titanic[titanic['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# media das idades 
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
# Descrição das idades 
titanic["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Descrição das taxas (Fare)
titanic["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# % mortos da tripulação 

titanic["Survived"].value_counts(normalize = True) * 100
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
titanic["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Valores maiores que 31 

titanic[titanic["Fare"] > 31].shape[0] / titanic.shape[0]
# Out:
# 0.24915824915824916

# %%
titanic[titanic["Fare"] > 31].shape[0]
# Out:
# 222

# %%
titanic[titanic["Fare"] > 31]["Fare"].mean()
# Out:
# 88.67787207207208

# %%
titanic[titanic["Fare"] > 31]["Fare"].describe()
# Out:
# count    222.000000
# mean      88.677872
# std       74.163197
# min       31.275000
# 25%       46.900000
# 50%       69.550000
# 75%       91.079200
# max      512.329200
# Name: Fare, dtype: float64

# %%
fig, ax = plt.subplots(figsize= (6,3))
titanic["Fare"].plot(kind = "hist", ax = ax, bins = 50)
plt.show()

# %%
titanic[titanic["Fare"] > 500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
# selecionando as pessoas que pagaram menos de 500 dólares no tiket 
titanic_filtrado = titanic[titanic["Fare"] < 500]

# %%
titanic_filtrado["Fare"].describe()
# Out:
# count    888.000000
# mean      30.582164
# std       41.176366
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       30.771850
# max      263.000000
# Name: Fare, dtype: float64

# %%
fig, ax = plt.subplots(figsize= (6,3))
titanic_filtrado["Fare"].plot(kind = "hist", ax = ax, bins = 50)
plt.show()

# %%
titanic_filtrado[titanic_filtrado["Fare"] > 100]["Fare"].describe()
# Out:
# count     50.000000
# mean     167.515078
# std       54.840151
# min      106.425000
# 25%      120.000000
# 50%      151.550000
# 75%      219.209400
# max      263.000000
# Name: Fare, dtype: float64

# %%
titanic_filtrado[titanic_filtrado["Fare"] < 100]["Fare"].describe()
# Out:
# count    838.000000
# mean      22.411942
# std       20.827218
# min        0.000000
# 25%        7.895800
# 50%       13.000000
# 75%       27.720800
# max       93.500000
# Name: Fare, dtype: float64

# %%
titanic_filtrado_2 = titanic_filtrado[titanic_filtrado["Fare"] < 100]

# %%
fig, ax = plt.subplots(figsize= (6,3))
titanic_filtrado_2["Fare"].plot(kind = "hist", ax = ax, bins = 50)
plt.show()

# %%
# vou utilizar apenas esta base de dados filtrada por motivos de ......
titanic_filtrado_2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_filtrado_2["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 2    184
# 1    163
# Name: count, dtype: int64

# %%
titanic_filtrado_2["Pclass"].value_counts(normalize = True).mul(100)
# Out:
# Pclass
# 3    58.591885
# 2    21.957041
# 1    19.451074
# Name: proportion, dtype: float64

# %%
titanic_filtrado_2[["Pclass", "Survived"]].value_counts(normalize = True).mul(100).sort_values()
# Out:
# Pclass  Survived
# 1       0            7.875895
# 2       1           10.381862
# 1       1           11.575179
# 2       0           11.575179
# 3       1           14.200477
#         0           44.391408
# Name: proportion, dtype: float64

# %% [markdown]
# # AGRUPAMENTOS NO PANDAS

# %%
titanic_filtrado_2.groupby(["Pclass", "Survived"]).size()
# Out:
# Pclass  Survived
# 1       0            66
#         1            97
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# dtype: int64

# %%
titanic_filtrado_2.groupby(["Pclass", "Survived"]).size() / titanic_filtrado_2.shape[0]
# Out:
# Pclass  Survived
# 1       0           0.078759
#         1           0.115752
# 2       0           0.115752
#         1           0.103819
# 3       0           0.443914
#         1           0.142005
# dtype: float64

# %%
titanic_filtrado_2.groupby("Pclass")["Age"].mean()
# Out:
# Pclass
# 1    40.416667
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
titanic_filtrado_2.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    50.703503
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
titanic_filtrado_2.groupby("Pclass")["Fare"].sum()
# Out:
# Pclass
# 1    8264.6710
# 2    3801.8417
# 3    6714.6951
# Name: Fare, dtype: float64

# %%
titanic_filtrado_2.groupby(["Pclass", "Survived"])["Fare"].sum()
# Out:
# Pclass  Survived
# 1       0           2708.7165
#         1           5555.9545
# 2       0           1882.9958
#         1           1918.8459
# 3       0           5085.0035
#         1           1629.6916
# Name: Fare, dtype: float64

# %%
titanic_filtrado_2.groupby(["Pclass"])[["Fare", "Age"]].mean()
# Out:
#              Fare        Age
# Pclass
# 1       50.703503  40.416667
# 2       20.662183  29.877630
# 3       13.675550  25.140620

# %%
titanic_filtrado_2.groupby(["Pclass"])["Fare"].agg(["mean","sum", "size"])
# Out:
#              mean        sum  size
# Pclass
# 1       50.703503  8264.6710   163
# 2       20.662183  3801.8417   184
# 3       13.675550  6714.6951   491

# %%
titanic_filtrado_2.groupby(["Pclass"]).agg(
                                    {
                                        "Fare": ["sum"],
                                        "Age": ["mean"]
                                    })
# Out:
#              Fare        Age
#               sum       mean
# Pclass
# 1       8264.6710  40.416667
# 2       3801.8417  29.877630
# 3       6714.6951  25.140620

# %%
titanic_filtrado_2.groupby(["Pclass"]).agg(
                                    {
                                        "Fare": ["sum", "median"],
                                        "Age": ["mean", "std"]
                                    })
# Out:
#              Fare               Age
#               sum median       mean        std
# Pclass
# 1       8264.6710  52.00  40.416667  14.305910
# 2       3801.8417  14.25  29.877630  14.001077
# 3       6714.6951   8.05  25.140620  12.495398

# %% [markdown]
# # outras ideias

# %%
titanic.isnull().sum() * 100 / titanic.shape[0]
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
titanic_sem_cabin = titanic.drop(columns = ["Cabin"])

# %%
titanic_sem_cabin.isnull().sum() * 100 / titanic_sem_cabin.shape[0]
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Embarked        0.224467
# dtype: float64

# %%
# limpar todos os dados nulos 
titanic_sem_cabin.dropna(inplace=True)

# %%
titanic_sem_cabin.isnull().sum() * 100 / titanic_sem_cabin.shape[0]
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_sem_embarked_nulo = titanic.dropna(subset = ["Embarked"])

# %%
titanic_sem_embarked_nulo.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
titanic_sem_embarked_nulo.to_csv("titanic_sem_embarked_nulo.csv", index = False)

# %%
titanic_sem_embarked_nulo.to_excel("titanic_sem_embarked_nulo.xlsx", index = False)

# %%
titanic[titanic["Name"].str.contains("Rose")]
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 855          856         1       3  Aks, Mrs. Sam (Leah Rosen)  female  18.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 855      0      1  392091  9.35   NaN        S

# %%
titanic[titanic["Name"].str.contains("ack")]
# Out:
#      PassengerId  Survived  Pclass  \
# 85            86         1       3
# 206          207         0       3
# 221          222         0       2
# 339          340         0       1
# 719          720         0       3
# 766          767         0       1
# 772          773         0       2
# 828          829         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 206                         Backstrom, Mr. Karl Alfred    male  32.0      1
# 221                               Bracken, Mr. James H    male  27.0      0
# 339                       Blackwell, Mr. Stephen Weart    male  45.0      0
# 719                       Johnson, Mr. Malkolm Joackim    male  33.0      0
# 766                          Brewe, Dr. Arthur Jackson    male   NaN      0
# 772                                  Mack, Mrs. (Mary)  female  57.0      0
# 828                       McCormack, Mr. Thomas Joseph    male   NaN      0
#
#      Parch       Ticket    Fare Cabin Embarked
# 85       0      3101278  15.850   NaN        S
# 206      0      3101278  15.850   NaN        S
# 221      0       220367  13.000   NaN        S
# 339      0       113784  35.500     T        S
# 719      0       347062   7.775   NaN        S
# 766      0       112379  39.600   NaN        C
# 772      0  S.O./P.P. 3  10.500   E77        S
# 828      0       367228   7.750   NaN        Q

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Para o Dataframe do Titanic

# %% [markdown]
# **1)** Faça a leitura do Dataframe e mostre as 5 primeiras linhas

# %% [markdown]
# **2)** Calcule a tarifa média por Sexo (Fare)

# %% [markdown]
# **3)** Determine o passageiro que pagou a maior tarifa

# %% [markdown]
# **4)** Determine a idade média dos sobreviventes

# %% [markdown]
# __5)__ Determinem a classe com mais sobreviventes proporcionalmente

# %% [markdown]
# ## Desafio

# %% [markdown]
# 1 - Escolha um dataset do [Kaggle](https://www.kaggle.com/), explore seus dados e traga uma informação interessante que você encontrou. Esta prática é bastante importante para familizariação com a exploração de dataframes

# %% [markdown]
# ## Links, Artigos e Referências:

# %% [markdown]
# - [Documentação do Pandas](https://pandas.pydata.org/docs/), documentação onde vocês podem encontrar mais informações sobre os métodos e funções do Pandas e descobrir novos métodos que não foram apresentados no curso;
# - ["10 Python Pandas Tricks that make your work more efficient",](https://towardsdatascience.com/10-python-pandas-tricks-that-make-your-work-more-efficient-2e8e483808ba) artigo escrito pelo Towards Data Science;
# - ["28 useful Pandas functions you might not know"](https://paulovasconcellos.com.br/28-useful-pandas-functions-you-might-not-know-de42c59db085https://medium.com/@zachary.bedell/writing-beautiful-code-with-numpy-505f3b353174), artigo escrito por Paulo Vasconcellos para o Data Hackers;

# %% [markdown]
# # PROJETO
#
# Tratamento e análise de dados com Pandas
#
# 1. Procurar um dataset (Conjunto de dados) interessante;
#     - Kaggle;
#     - UCI Datasets;
#     - IBGE;
#     - Outras fontes de interesse.
# 2. Descrever os dados (nulos, valores distintos, tipos de variáveis...);
# 3. Fazer o tratamento de qualidade dos dados (Remover nulos, remover valores constantes, ...)
# 4. Levantar 5 perguntas sobre o dataset e responder utilizado filtragens, agrupamentos e transformações no Pandas.
#
# Entrega:
#
# - Repositório do github (Envie o link do repositório);
# - Pelo menos 3 commits no github ;
# - No repositório deve conter o dataset e o arquivo .ipynb;
# - Entrega até o dia 26/04 no LMS (até 17h);
